# %% [markdown]
# Уважаемые студенты!
#
# Задачи выполняются с помощью стандартных библиотек питона без установки сторонних библиотек. Все задачи направлены на проверку усвоения пройденного материала. Вспомните как работать с библиотекой Pandas.
#
# Желаем удачи!

# %% [markdown]
# **Задача №1**. **Создание и базовый анализ DataFrame:**
#
# - Создайте DataFrame из словаря, где ключи — имена столбцов, а значения — списки данных.
# - Выполните базовый анализ данных с помощью методов head(), info(), describe() и shape.

# %%
import pandas as pd

data = {
    'Имя': ['Анна', 'Борис', 'Виктор', 'Галина', 'Дмитрий'],
    'Возраст': [23, 30, 35, 29, 40],
    'Город': ['Москва', 'Санкт-Петербург', 'Новосибирск', 'Екатеринбург', 'Казань']
}

df = pd.DataFrame(data)
print(df.head(), "\n")
print(df.info(), "\n")
print(df.describe(), "\n")
print(f"Количество строк: {df.shape[0]}, Количество столбцов: {df.shape[1]}")
# Out:
#        Имя  Возраст            Город
# 0     Анна       23           Москва
# 1    Борис       30  Санкт-Петербург
# 2   Виктор       35      Новосибирск
# 3   Галина       29     Екатеринбург
# 4  Дмитрий       40           Казань
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Имя      5 non-null      object
#  1   Возраст  5 non-null      int64
#  2   Город    5 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 252.0+ bytes
# None
#
#          Возраст
# count   5.000000
# mean   31.400000
# std     6.426508
# min    23.000000
# 25%    29.000000
# 50%    30.000000
# 75%    35.000000
# max    40.000000
#
# Количество строк: 5, Количество столбцов: 3

# %% [markdown]
# **Задача №2**. **Работа с индексами и фильтрация:**
#
# - Отфильтруйте строки, основываясь на значениях в одном или нескольких столбцах.

# %%
import pandas as pd

data = {
    'Имя': ['Анна', 'Борис', 'Виктор', 'Галина', 'Дмитрий'],
    'Возраст': [23, 30, 35, 29, 40],
    'Город': ['Москва', 'Санкт-Петербург', 'Новосибирск', 'Екатеринбург', 'Казань']
}

df = pd.DataFrame(data)
print(df.sort_values(by='Возраст', ascending=False).head(), "\n")
print(df.sort_values(by=['Возраст', 'Имя'], ascending=[True, False]))
# Out:
#        Имя  Возраст            Город
# 4  Дмитрий       40           Казань
# 2   Виктор       35      Новосибирск
# 1    Борис       30  Санкт-Петербург
# 3   Галина       29     Екатеринбург
# 0     Анна       23           Москва
#
#        Имя  Возраст            Город
# 0     Анна       23           Москва
# 3   Галина       29     Екатеринбург
# 1    Борис       30  Санкт-Петербург
# 2   Виктор       35      Новосибирск
# 4  Дмитрий       40           Казань

# %% [markdown]
# **Задача №3**. **Обработка отсутствующих данных:**
#
#   - Заполните отсутствующие значения методом fillna(), используя среднее значение по столбцу.
#   - Удалите строки с отсутствующими значениями методом dropna().

# %%
import numpy as np
import pandas as pd

data = {
    'Имя': ['Анна', 'Борис', 'Виктор', 'Галина', 'Дмитрий'],
    'Возраст': [23, np.nan, 35, 29, np.nan],
    'Город': ['Москва', 'Санкт-Петербург', 'Новосибирск', None, 'Казань']
}

df = pd.DataFrame(data)

mean_age = df['Возраст'].mean()
df['Возраст'] = df['Возраст'].fillna(mean_age)

df = df.dropna()
print(df)
# Out:
#        Имя  Возраст            Город
# 0     Анна     23.0           Москва
# 1    Борис     29.0  Санкт-Петербург
# 2   Виктор     35.0      Новосибирск
# 4  Дмитрий     29.0           Казань

# %% [markdown]
# **Задача №4**. **Группировка и агрегирование данных:**
#    - Создайте DataFrame из словаря и выполните его группировку по определённым категориям.
#    - Используйте методы groupby() и agg() для получения суммарных и средних значений по группе.

# %%
import pandas as pd

data = {
    'Группа': ['A', 'B', 'A', 'B', 'A'],
    'Значение': [10, 20, 15, 25, 40]
}

df = pd.DataFrame(data)
grouped_data = df.groupby('Группа')['Значение'].agg([
    ('Сумма', 'sum'),
    ('Среднее', 'mean'),
])
print(grouped_data)
# Out:
#         Сумма    Среднее
# Группа
# A          65  21.666667
# B          45  22.500000

# %% [markdown]
# **Задача №5**. **Объединение и слияние DataFrame:**
#    - Создайте два DataFrame из словарей.
#    - Примените методы merge() и concat(), чтобы объединить эти DataFrame разными способами.

# %%
import pandas as pd

data1 = {
    'Имя': ['Анна', 'Борис'],
    'Возраст': [23, 30]
}

data2 = {
    'Имя': ['Виктор', 'Галина'],
    'Возраст': [35, 29]
}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

df12 = pd.concat([df1, df2], ignore_index=True)
print(df12, "\n")

#датафрейм из задания 2 чтобы было по чему делать merge
data = {
    'Имя': ['Анна', 'Борис', 'Виктор', 'Галина', 'Дмитрий'],
    'Город': ['Москва', 'Санкт-Петербург', 'Новосибирск', 'Екатеринбург', 'Казань']
}

df = pd.DataFrame(data)
df_merge1 = pd.merge(df1, df, on='Имя')
print(df_merge1, "\n")
df_merge2 = pd.merge(df2, df, on='Имя')
print(df_merge2, "\n")
# Out:
#       Имя  Возраст
# 0    Анна       23
# 1   Борис       30
# 2  Виктор       35
# 3  Галина       29
#
#      Имя  Возраст            Город
# 0   Анна       23           Москва
# 1  Борис       30  Санкт-Петербург
#
#       Имя  Возраст         Город
# 0  Виктор       35   Новосибирск
# 1  Галина       29  Екатеринбург

# %% [markdown]
# **Задача №6**. **Применение функций к данным:**
#   - Создайте DataFrame из словаря и используйте метод apply() для преобразования данных в колонке "Возраст" (например, умножьте все значения на 2).

# %%
import pandas as pd

data = {
    'Имя': ['Анна', 'Борис', 'Виктор'],
    'Возраст': [23, 30, 35]
}

df = pd.DataFrame(data)
df['Возраст'] = df['Возраст'].apply(lambda x: x * 2)
print(df)
# Out:
#       Имя  Возраст
# 0    Анна       46
# 1   Борис       60
# 2  Виктор       70

# %% [markdown]
# **Задача №7**. **Временные ряды и данные по дате и времени:**
#   - Создайте DataFrame с временными данными, используя pd.date_range().
#   - Выполните операции ресемплирования (resample()) для агрегирования данных на основе временных интервалов.

# %%
import pandas as pd

date_range = date_range = pd.date_range(start='2025-01-01', periods=5, freq='D')
data = {
    'Дата': date_range,
    'Значение': [100, 150, 200, 250, 300]
}

df = pd.DataFrame(data) #исходный датафрейм
print(df, "\n")
df.set_index('Дата', inplace=True)

print(df.resample('W').sum(), "\n") #сумма по неделям
print(df.resample('2D').mean(), "\n") #среднее по двум дням
print(df.resample('W').mean(), "\n") #среднее по неделям
print(df.resample('W').max(), "\n") #максимум по неделям
print(df.resample('W').min(), "\n") #минимум по неделям
# Out:
#         Дата  Значение
# 0 2025-01-01       100
# 1 2025-01-02       150
# 2 2025-01-03       200
# 3 2025-01-04       250
# 4 2025-01-05       300
#
#             Значение
# Дата
# 2025-01-05      1000
#
#             Значение
# Дата
# 2025-01-01     125.0
# 2025-01-03     225.0
# 2025-01-05     300.0
#
#             Значение
# Дата
# 2025-01-05     200.0
#
#             Значение
# Дата
# 2025-01-05       300
#
#             Значение
# Дата
# 2025-01-05       100

# %% [markdown]
# **Задача №8**. **Визуализация данных с помощью Pandas**
#   - Создайте DataFrame из словаря
#   - Постройте диаграмму для вашего DataFrame используя matplotlib.pyplot.

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    'Имя': ['Анна', 'Борис', 'Виктор', 'Галина', 'Дмитрий'],
    'Возраст': [23, 30, 35, 29, 40]
}

df = pd.DataFrame(data)

plt.figure(figsize=(8, 5))
plt.bar(df['Имя'], df['Возраст'])

plt.title('Возраст людей')
plt.xlabel('Имя')
plt.ylabel('Возраст')
plt.grid(axis='y', linestyle='--', alpha=0.5)

for i, age in enumerate(df['Возраст']):
    plt.text(i, age + 0.5, str(age), ha='center')

plt.show()
